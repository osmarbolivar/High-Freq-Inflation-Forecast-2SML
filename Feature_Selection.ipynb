# %% [markdown]
# # <font color="red">**STEP 2: FEATURE SELECTION**</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import plotly.graph_objects as go

# %%
# Correlation matrix
def lagged_correlation_color(df, specific_var, l=0):
    lags = [l]
    # Create lagged versions of the DataFrame
    lagged_df = pd.concat([df.shift(lag) for lag in lags], axis=1, keys=[f'Lag{lag}' for lag in lags])
    # Calculate correlation coefficients
    correlations = lagged_df.corrwith(df[specific_var])
    # Sort correlations from highest to lowest
    correlations_sorted = correlations.sort_values(ascending=False)
    # Convert the sorted correlations to a data frame and reset index
    df_correlations_sorted = pd.DataFrame(correlations_sorted, columns=['corr']).reset_index()

    lagged_df.columns = df.columns
    return df_correlations_sorted, lagged_df

col_range = range(0,1)


# Growth Rate datafrmaes
def preprocess_data(df, period):
    df_copy = df.copy().pct_change(period).dropna(axis=0)
    df_copy = df_copy.loc[:, np.isfinite(df_copy).all(axis=0)]
    return df_copy.dropna(axis=1)

# %% [markdown]
# ## **1. Feature Selection (FS)**

# %%
dataset_m = pd.read_csv("./Data/M_DATASET.csv", index_col=0)
dataset_m['exchange'] = 1/dataset_m['exchange']  ## to ensure a positive correlation
dataset_m
# Out:
#                ipc_all       lag_1       lag_2       lag_3       lag_6  \
# 2011-01-31   74.207255   73.260267   71.989803   71.196381   69.071086
# 2011-02-28   75.439060   74.207255   73.260267   71.989803   69.800954
# 2011-03-31   76.108818   75.439060   74.207255   73.260267   70.335479
# 2011-04-30   76.125495   76.108818   75.439060   74.207255   71.196381
# 2011-05-31   76.277495   76.125495   76.108818   75.439060   71.989803
# ...                ...         ...         ...         ...         ...
# 2023-11-30  110.425657  110.429431  110.440281  110.506839  109.439785
# 2023-12-31  111.123491  110.425657  110.429431  110.440281  109.678594
# 2024-01-31  111.211060  111.123491  110.425657  110.429431  110.081702
# 2024-02-29  111.433348  111.211060  111.123491  110.425657  110.506839
# 2024-03-31  111.941559  111.433348  111.211060  111.123491  110.440281
#
#                  lag_9      lag_12    beef_lp    beef_cb    beef_sc  ...  \
# 2011-01-31   68.561311   68.467691  18.492308  20.980769  18.450000  ...
# 2011-02-28   68.549203   68.581371  18.720833  20.500000  18.385000  ...
# 2011-03-31   68.646613   68.499278  19.166667  20.518519  18.140370  ...
# 2011-04-30   69.071086   68.561311  19.076923  19.153846  17.835769  ...
# 2011-05-31   69.800954   68.549203  19.000000  18.884615  17.827692  ...
# ...                ...         ...        ...        ...        ...  ...
# 2023-11-30  108.697854  108.692935  23.211200  23.000000  21.000000  ...
# 2023-12-31  108.614602  108.818364  23.223333  23.000000  21.000000  ...
# 2024-01-31  108.814654  109.176930  24.120909  23.965909  20.954545  ...
# 2024-02-29  109.439785  108.697854  23.987391  24.956522  21.000000  ...
# 2024-03-31  109.678594  108.614602  22.630000  24.000000  21.000000  ...
#
#             inflacion  inflacion en bolivia  inflación bolivia  ipc  \
# 2011-01-31         58                    59                100   79
# 2011-02-28         63                    44                100   79
# 2011-03-31         82                    78                100   54
# 2011-04-30        100                    90                100   93
# 2011-05-31         75                    68                100   88
# ...               ...                   ...                ...  ...
# 2023-11-30         41                    39                 59   54
# 2023-12-31         31                    39                 68   67
# 2024-01-31         29                    38                 64   86
# 2024-02-29         31                    38                 58   66
# 2024-03-31         28                    37                 50   65
#
#             la inflacion  la inflación  pib  pib bolivia  que es inflacion  \
# 2011-01-31            44            33   50           29               100
# 2011-02-28            45            33   59           51               100
# 2011-03-31            57            33   92           77               100
# 2011-04-30           100            33   98           77               100
# 2011-05-31            73            33   78           69                89
# ...                  ...           ...  ...          ...               ...
# 2023-11-30            53            44   47           37                42
# 2023-12-31            55            51   35           24                54
# 2024-01-31            43            46   30           27                53
# 2024-02-29            38            38   37           34                51
# 2024-03-31            47            51   56           36                47
#
#             que es pib
# 2011-01-31          54
# 2011-02-28          54
# 2011-03-31          54
# 2011-04-30          59
# 2011-05-31          56
# ...                ...
# 2023-11-30          38
# 2023-12-31          44
# 2024-01-31          43
# 2024-02-29          41
# 2024-03-31          61
#
# [159 rows x 492 columns]

# %% [markdown]
# ### **1.1. Correlation-based FS**
#
# It is a filter technique.

# %%
ldf_corr = dataset_m.dropna(axis=1)

g12df_corr = preprocess_data(ldf_corr, 12)
g1df_corr = preprocess_data(ldf_corr, 1)

# %%
lcorr_lag0, ldf_lag0 = lagged_correlation_color(ldf_corr, 'ipc_all', 0)
lcorr_lag0.head(10)

corr_plus05 = np.array(lcorr_lag0.query('corr > 0.5')['level_1'])
corr_minus05 = np.array(lcorr_lag0.query('corr < -0.5')['level_1'])

corr_plus05, corr_minus05
# Out:
# c:\Users\osmar.bolivar\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\osmar.bolivar\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# (array(['ipc_all', 'lag_1', 'lag_2', 'lag_3', 'ufv', 'lag_6', 'lag_9',
#         'lag_12', 'milk_lp', 'milk_or', 'milk_bol', 'paprika_tr',
#         'milk_sc', 'milk_su', 'beef_lp', 'milk_po', 'squash_tr',
#         'banana_co', 'milk_cb', 'corn_co', 'papaya_tr', 'milk2_po',
#         'milk2_or', 'apple_sc', 'wheat_sc', 'beef_su', 'beef_bol',
#         'rice3_co', 'onion2_po', 'sorghum_lp', 'redpepper_tr', 'flour_tj',
#         'banana_bol', 'rice2_co', 'apple_or', 'rice_co', 'banana_tj',
#         'beef_or', 'dinero', 'flour_po', 'beef_sc', 'grapefruit_po',
#         'bean_tr', 'greenbean_tr', 'beef_cb', 'libor', 'banana_tr',
#         'rice4_or', 'zinc', 'grapefruit_bol', 'banana_sc', 'pineapple_or',
#         'grapefruit_cb', 'redpepper_po', 'banana_su', 'wheat_po',
#         'milk2_lp', 'veglard_co', 'banana_lp', 'peas_tr', 'beef_tr',
#         'grapefruit_or', 'oil_co', 'rice2_or', 'soy_po', 'grapefruit_su',
#         'platano_tr', 'beef_po'], dtype=object),
#  array(['platano_co', 'silver', 'oil_po', 'sugar_or', 'rice3_su',
#         'platano_su', 'sugar_po', 'chili_tj', 'sugar_bol', 'quinoa_su',
#         'watermelon_po', 'onion2_co', 'sugar_tj', 'oil2_po', 'sugar_su',
#         'chicken_tj', 'platano_tj', 'rice4_tj', 'oil2_sc', 'oil2_tj',
#         'apple_tr', 'oil2_bol', 'papa2_tj', 'lard_or', 'oil2_su', 'oil_su',
#         'redpepper_co', 'oil_cb', 'carrot_co', 'pineapple_co', 'oil2_or',
#         'peas_co', 'wheat_lp', 'squash_co', 'rice4_su', 'onion2_tj',
#         'lard_co'], dtype=object))

# %%
CORR_M_DATASET = dataset_m[corr_plus05]
CORR_M_DATASET.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 159 entries, 2011-01-31 to 2024-03-31
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ipc_all         159 non-null    float64
#  1   lag_1           159 non-null    float64
#  2   lag_2           159 non-null    float64
#  3   lag_3           159 non-null    float64
#  4   ufv             159 non-null    float64
#  5   lag_6           159 non-null    float64
#  6   lag_9           159 non-null    float64
#  7   lag_12          159 non-null    float64
#  8   milk_lp         159 non-null    float64
#  9   milk_or         159 non-null    float64
#  10  milk_bol        159 non-null    float64
#  11  paprika_tr      159 non-null    float64
#  12  milk_sc         159 non-null    float64
#  13  milk_su         159 non-null    float64
#  14  beef_lp         159 non-null    float64
#  15  milk_po         159 non-null    float64
#  16  squash_tr       159 non-null    float64
#  17  banana_co       159 non-null    float64
#  18  milk_cb         159 non-null    float64
#  19  corn_co         159 non-null    float64
#  20  papaya_tr       159 non-null    float64
#  21  milk2_po        159 non-null    float64
#  22  milk2_or        159 non-null    float64
#  23  apple_sc        159 non-null    float64
#  24  wheat_sc        159 non-null    float64
#  25  beef_su         159 non-null    float64
#  26  beef_bol        159 non-null    float64
#  27  rice3_co        159 non-null    float64
#  28  onion2_po       159 non-null    float64
#  29  sorghum_lp      159 non-null    float64
#  30  redpepper_tr    159 non-null    float64
#  31  flour_tj        159 non-null    float64
#  32  banana_bol      159 non-null    float64
#  33  rice2_co        159 non-null    float64
#  34  apple_or        159 non-null    float64
#  35  rice_co         159 non-null    float64
#  36  banana_tj       159 non-null    float64
#  37  beef_or         159 non-null    float64
#  38  dinero          159 non-null    int64
#  39  flour_po        159 non-null    float64
#  40  beef_sc         159 non-null    float64
#  41  grapefruit_po   159 non-null    float64
#  42  bean_tr         159 non-null    float64
#  43  greenbean_tr    159 non-null    float64
#  44  beef_cb         159 non-null    float64
#  45  libor           159 non-null    float64
#  46  banana_tr       159 non-null    float64
#  47  rice4_or        159 non-null    float64
#  48  zinc            159 non-null    float64
#  49  grapefruit_bol  159 non-null    float64
#  50  banana_sc       159 non-null    float64
#  51  pineapple_or    159 non-null    float64
#  52  grapefruit_cb   159 non-null    float64
#  53  redpepper_po    159 non-null    float64
#  54  banana_su       159 non-null    float64
#  55  wheat_po        159 non-null    float64
#  56  milk2_lp        159 non-null    float64
#  57  veglard_co      159 non-null    float64
#  58  banana_lp       159 non-null    float64
#  59  peas_tr         159 non-null    float64
#  60  beef_tr         159 non-null    float64
#  61  grapefruit_or   159 non-null    float64
#  62  oil_co          159 non-null    float64
#  63  rice2_or        159 non-null    float64
#  64  soy_po          159 non-null    float64
#  65  grapefruit_su   159 non-null    float64
#  66  platano_tr      159 non-null    float64
#  67  beef_po         159 non-null    float64
# dtypes: float64(67), int64(1)
# memory usage: 85.7+ KB

# %% [markdown]
# ### **1.2. Principal Component FS**

# %% [markdown]
# ### **1.3. L1-LR FS**

# %% [markdown]
# ### **1.4. Random Forest FS**
